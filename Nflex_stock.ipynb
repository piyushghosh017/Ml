# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib

# %%
df=pd.read_csv('NFLX_train.csv')
df.head(6)
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2013-01-02  13.601429  13.687143  12.955714  13.144286  13.144286  19431300
# 1  2013-01-03  13.138572  13.988571  13.075714  13.798572  13.798572  27912500
# 2  2013-01-04  13.791429  13.958571  13.648571  13.711429  13.711429  17761100
# 3  2013-01-07  13.770000  14.535714  13.731428  14.171429  14.171429  45550400
# 4  2013-01-08  14.287143  14.427143  13.828571  13.880000  13.880000  24714900
# 5  2013-01-09  13.874286  13.992857  13.507143  13.701428  13.701428  20223000

# %%
df.shape
# Out:
# (1259, 7)

# %%
# visualize
plt.figure(figsize=(16,8))
plt.title('Netflix')
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(df["Close"])
plt.show()

# %%
df['Close'].head()
# Out:
# 0    13.144286
# 1    13.798572
# 2    13.711429
# 3    14.171429
# 4    13.880000
# Name: Close, dtype: float64
